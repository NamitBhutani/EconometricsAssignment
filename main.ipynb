# %%
import pandas as pd
# Out:
# /tmp/ipykernel_112327/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv("mysavefile.csv")
data.shape
# Out:
# /tmp/ipykernel_112327/4162313240.py:1: DtypeWarning: Columns (10,46,51,72,222,324,325,326,330,331) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("mysavefile.csv")
# (204569, 338)

# %%
data.head(5)
# Out:
#    Unnamed: 0         SURVEY                  STATEID  DISTID  PSUID  HHID  \
# 0           1  (2) IHDS-II 2  (01) Jammu & Kashmir 01       2      1    10
# 1           2  (2) IHDS-II 2  (01) Jammu & Kashmir 01       2      1    10
# 2           3  (2) IHDS-II 2  (01) Jammu & Kashmir 01       2      1    10
# 3           4  (2) IHDS-II 2  (01) Jammu & Kashmir 01       2      1    10
# 4           5  (2) IHDS-II 2  (01) Jammu & Kashmir 01       2      1    10
#
#    HHSPLITID  PERSONID  IDPSU       IDHH  ... MG8  \
# 0          1       1.0  10201  102010101  ... NaN
# 1          1       2.0  10201  102010101  ... NaN
# 2          1       3.0  10201  102010101  ... NaN
# 3          1       4.0  10201  102010101  ... NaN
# 4          1       5.0  10201  102010101  ... NaN
#
#                                       MG9NM  MG10  MG11   MGYEAR5 NMIG5  \
# 0                                             NaN   NaN  (0) No 0   NaN
# ...

# %%
def clean_cols(data):
    data_columns = list(data.columns)
    for i in data_columns:
        if i == 'Unnamed: 0':
            data = data.drop(columns=['Unnamed: 0'])
        else:
            break
    return data

clean_cols(data)
# Out:
#                SURVEY                  STATEID  DISTID  PSUID  HHID  \
# 0       (2) IHDS-II 2  (01) Jammu & Kashmir 01       2      1    10
# 1       (2) IHDS-II 2  (01) Jammu & Kashmir 01       2      1    10
# 2       (2) IHDS-II 2  (01) Jammu & Kashmir 01       2      1    10
# 3       (2) IHDS-II 2  (01) Jammu & Kashmir 01       2      1    10
# 4       (2) IHDS-II 2  (01) Jammu & Kashmir 01       2      1    10
# ...               ...                      ...     ...    ...   ...
# 204564  (2) IHDS-II 2      (34) Pondicherry 34       0      6   130
# 204565  (2) IHDS-II 2      (34) Pondicherry 34       0      6   140
# 204566  (2) IHDS-II 2      (34) Pondicherry 34       0      6   140
# 204567  (2) IHDS-II 2      (34) Pondicherry 34       0      6   140
# 204568  (2) IHDS-II 2      (34) Pondicherry 34       0      6   140
#
#         HHSPLITID  PERSONID   IDPSU        IDHH      IDPERSON  ...  MG8  \
# 0               1       1.0   10201   102010101   10201010101  ...  NaN
# ...

# %%
data.head(5)
# Out:
#    Unnamed: 0         SURVEY                  STATEID  DISTID  PSUID  HHID  \
# 0           1  (2) IHDS-II 2  (01) Jammu & Kashmir 01       2      1    10
# 1           2  (2) IHDS-II 2  (01) Jammu & Kashmir 01       2      1    10
# 2           3  (2) IHDS-II 2  (01) Jammu & Kashmir 01       2      1    10
# 3           4  (2) IHDS-II 2  (01) Jammu & Kashmir 01       2      1    10
# 4           5  (2) IHDS-II 2  (01) Jammu & Kashmir 01       2      1    10
#
#    HHSPLITID  PERSONID  IDPSU       IDHH  ... MG8  \
# 0          1       1.0  10201  102010101  ... NaN
# 1          1       2.0  10201  102010101  ... NaN
# 2          1       3.0  10201  102010101  ... NaN
# 3          1       4.0  10201  102010101  ... NaN
# 4          1       5.0  10201  102010101  ... NaN
#
#                                       MG9NM  MG10  MG11   MGYEAR5 NMIG5  \
# 0                                             NaN   NaN  (0) No 0   NaN
# ...
